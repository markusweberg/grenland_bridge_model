# %% [markdown]
# Bridge deck

# %%
import numpy as np

# %%
bridge_deck_x_cord = np.arange(0, 609, 1)

# Nodes
for i in range(len(x_cord)):
    print(f"{i+1}, {round(x_cord[i],3)}, 0, 51")
# Out:
# 1, 0, 0, 51
# 2, 1, 0, 51
# 3, 2, 0, 51
# 4, 3, 0, 51
# 5, 4, 0, 51
# 6, 5, 0, 51
# 7, 6, 0, 51
# 8, 7, 0, 51
# 9, 8, 0, 51
# 10, 9, 0, 51
# 11, 10, 0, 51
# 12, 11, 0, 51
# 13, 12, 0, 51
# 14, 13, 0, 51
# 15, 14, 0, 51
# 16, 15, 0, 51
# 17, 16, 0, 51
# 18, 17, 0, 51
# 19, 18, 0, 51
# 20, 19, 0, 51
# 21, 20, 0, 51
# 22, 21, 0, 51
# 23, 22, 0, 51
# 24, 23, 0, 51
# 25, 24, 0, 51
# 26, 25, 0, 51
# 27, 26, 0, 51
# 28, 27, 0, 51
# 29, 28, 0, 51
# 30, 29, 0, 51
# 31, 30, 0, 51
# 32, 31, 0, 51
# 33, 32, 0, 51
# 34, 33, 0, 51
# 35, 34, 0, 51
# 36, 35, 0, 51
# 37, 36, 0, 51
# 38, 37, 0, 51
# 39, 38, 0, 51
# 40, 39, 0, 51
# 41, 40, 0, 51
# 42, 41, 0, 51
# 43, 42, 0, 51
# 44, 43, 0, 51
# 45, 44, 0, 51
# 46, 45, 0, 51
# 47, 46, 0, 51
# 48, 47, 0, 51
# 49, 48, 0, 51
# 50, 49, 0, 51
# 51, 50, 0, 51
# 52, 51, 0, 51
# 53, 52, 0, 51
# 54, 53, 0, 51
# 55, 54, 0, 51
# 56, 55, 0, 51
# 57, 56, 0, 51
# 58, 57, 0, 51
# 59, 58, 0, 51
# 60, 59, 0, 51
# 61, 60, 0, 51
# 62, 61, 0, 51
# 63, 62, 0, 51
# ...

# %%
# Elements
for i in range(len(bridge_deck_x_cord)-1):
    print(f"{i+1}, {i+1}, {i+2}")
# Out:
# 1, 1, 2
# 2, 2, 3
# 3, 3, 4
# 4, 4, 5
# 5, 5, 6
# 6, 6, 7
# 7, 7, 8
# 8, 8, 9
# 9, 9, 10
# 10, 10, 11
# 11, 11, 12
# 12, 12, 13
# 13, 13, 14
# 14, 14, 15
# 15, 15, 16
# 16, 16, 17
# 17, 17, 18
# 18, 18, 19
# 19, 19, 20
# 20, 20, 21
# 21, 21, 22
# 22, 22, 23
# 23, 23, 24
# 24, 24, 25
# 25, 25, 26
# 26, 26, 27
# 27, 27, 28
# 28, 28, 29
# 29, 29, 30
# 30, 30, 31
# 31, 31, 32
# 32, 32, 33
# 33, 33, 34
# 34, 34, 35
# 35, 35, 36
# 36, 36, 37
# 37, 37, 38
# 38, 38, 39
# 39, 39, 40
# 40, 40, 41
# 41, 41, 42
# 42, 42, 43
# 43, 43, 44
# 44, 44, 45
# 45, 45, 46
# 46, 46, 47
# 47, 47, 48
# 48, 48, 49
# 49, 49, 50
# 50, 50, 51
# 51, 51, 52
# 52, 52, 53
# 53, 53, 54
# 54, 54, 55
# 55, 55, 56
# 56, 56, 57
# 57, 57, 58
# 58, 58, 59
# 59, 59, 60
# 60, 60, 61
# 61, 61, 62
# 62, 62, 63
# 63, 63, 64
# 64, 64, 65
# 65, 65, 66
# 66, 66, 67
# 67, 67, 68
# 68, 68, 69
# 69, 69, 70
# 70, 70, 71
# 71, 71, 72
# 72, 72, 73
# 73, 73, 74
# 74, 74, 75
# 75, 75, 76
# 76, 76, 77
# 77, 77, 78
# 78, 78, 79
# ...

# %% [markdown]
# Main tower

# %%
# Nodes for west side
main_tower_west_y_cord = np.linspace(-9.5, -6, 130)
main_tower_west_z_cord = np.arange(0, 165, 1)

for i in range(len(main_tower_west_z_cord)):
    if i < 130:
        print(f"{i+610}, 67, {round(main_tower_west_y_cord[i],2)}, {main_tower_west_z_cord[i]}")
    else:
        print(f"{i+610}, 67, -6, {main_tower_west_z_cord[i]}")
# Out:
# 610, 67, -9.5, 0
# 611, 67, -9.47, 1
# 612, 67, -9.45, 2
# 613, 67, -9.42, 3
# 614, 67, -9.39, 4
# 615, 67, -9.36, 5
# 616, 67, -9.34, 6
# 617, 67, -9.31, 7
# 618, 67, -9.28, 8
# 619, 67, -9.26, 9
# 620, 67, -9.23, 10
# 621, 67, -9.2, 11
# 622, 67, -9.17, 12
# 623, 67, -9.15, 13
# 624, 67, -9.12, 14
# 625, 67, -9.09, 15
# 626, 67, -9.07, 16
# 627, 67, -9.04, 17
# 628, 67, -9.01, 18
# 629, 67, -8.98, 19
# 630, 67, -8.96, 20
# 631, 67, -8.93, 21
# 632, 67, -8.9, 22
# 633, 67, -8.88, 23
# 634, 67, -8.85, 24
# 635, 67, -8.82, 25
# 636, 67, -8.79, 26
# 637, 67, -8.77, 27
# 638, 67, -8.74, 28
# 639, 67, -8.71, 29
# 640, 67, -8.69, 30
# 641, 67, -8.66, 31
# 642, 67, -8.63, 32
# 643, 67, -8.6, 33
# 644, 67, -8.58, 34
# 645, 67, -8.55, 35
# 646, 67, -8.52, 36
# 647, 67, -8.5, 37
# 648, 67, -8.47, 38
# 649, 67, -8.44, 39
# 650, 67, -8.41, 40
# 651, 67, -8.39, 41
# 652, 67, -8.36, 42
# 653, 67, -8.33, 43
# 654, 67, -8.31, 44
# 655, 67, -8.28, 45
# 656, 67, -8.25, 46
# 657, 67, -8.22, 47
# ...

# %%
# Elements for west side
for i in range(len(main_tower_west_z_cord)-1):
    print(f"{i+609}, {i+610}, {i+611}")
# Out:
# 609, 610, 611
# 610, 611, 612
# 611, 612, 613
# 612, 613, 614
# 613, 614, 615
# 614, 615, 616
# 615, 616, 617
# 616, 617, 618
# 617, 618, 619
# 618, 619, 620
# 619, 620, 621
# 620, 621, 622
# 621, 622, 623
# 622, 623, 624
# 623, 624, 625
# 624, 625, 626
# 625, 626, 627
# 626, 627, 628
# 627, 628, 629
# 628, 629, 630
# 629, 630, 631
# 630, 631, 632
# 631, 632, 633
# 632, 633, 634
# 633, 634, 635
# 634, 635, 636
# 635, 636, 637
# 636, 637, 638
# 637, 638, 639
# 638, 639, 640
# 639, 640, 641
# 640, 641, 642
# 641, 642, 643
# 642, 643, 644
# 643, 644, 645
# 644, 645, 646
# 645, 646, 647
# 646, 647, 648
# 647, 648, 649
# 648, 649, 650
# 649, 650, 651
# 650, 651, 652
# 651, 652, 653
# 652, 653, 654
# 653, 654, 655
# 654, 655, 656
# 655, 656, 657
# 656, 657, 658
# 657, 658, 659
# 658, 659, 660
# 659, 660, 661
# 660, 661, 662
# 661, 662, 663
# 662, 663, 664
# 663, 664, 665
# 664, 665, 666
# 665, 666, 667
# 666, 667, 668
# 667, 668, 669
# 668, 669, 670
# 669, 670, 671
# 670, 671, 672
# ...

# %%
# Nodes for east side
main_tower_east_y_cord = np.linspace(9.5, 6, 130)
main_tower_east_z_cord = np.arange(0, 165, 1)

for i in range(len(main_tower_east_z_cord)):
    if i < 130:
        print(f"{i+775}, 67, {round(main_tower_east_y_cord[i],2)}, {main_tower_east_z_cord[i]}")
    else:
        print(f"{i+775}, 67, 6, {main_tower_east_z_cord[i]}")
# Out:
# 775, 67, 9.5, 0
# 776, 67, 9.47, 1
# 777, 67, 9.45, 2
# 778, 67, 9.42, 3
# 779, 67, 9.39, 4
# 780, 67, 9.36, 5
# 781, 67, 9.34, 6
# 782, 67, 9.31, 7
# 783, 67, 9.28, 8
# 784, 67, 9.26, 9
# 785, 67, 9.23, 10
# 786, 67, 9.2, 11
# 787, 67, 9.17, 12
# 788, 67, 9.15, 13
# 789, 67, 9.12, 14
# 790, 67, 9.09, 15
# 791, 67, 9.07, 16
# 792, 67, 9.04, 17
# 793, 67, 9.01, 18
# 794, 67, 8.98, 19
# 795, 67, 8.96, 20
# 796, 67, 8.93, 21
# 797, 67, 8.9, 22
# 798, 67, 8.88, 23
# 799, 67, 8.85, 24
# 800, 67, 8.82, 25
# 801, 67, 8.79, 26
# 802, 67, 8.77, 27
# 803, 67, 8.74, 28
# 804, 67, 8.71, 29
# 805, 67, 8.69, 30
# 806, 67, 8.66, 31
# 807, 67, 8.63, 32
# 808, 67, 8.6, 33
# 809, 67, 8.58, 34
# 810, 67, 8.55, 35
# 811, 67, 8.52, 36
# 812, 67, 8.5, 37
# 813, 67, 8.47, 38
# 814, 67, 8.44, 39
# 815, 67, 8.41, 40
# 816, 67, 8.39, 41
# 817, 67, 8.36, 42
# 818, 67, 8.33, 43
# 819, 67, 8.31, 44
# 820, 67, 8.28, 45
# 821, 67, 8.25, 46
# 822, 67, 8.22, 47
# 823, 67, 8.2, 48
# 824, 67, 8.17, 49
# ...

# %%
# Elements for east side
for i in range(len(main_tower_east_z_cord)-1):
    print(f"{i+773}, {i+775}, {i+776}")
# Out:
# 773, 775, 776
# 774, 776, 777
# 775, 777, 778
# 776, 778, 779
# 777, 779, 780
# 778, 780, 781
# 779, 781, 782
# 780, 782, 783
# 781, 783, 784
# 782, 784, 785
# 783, 785, 786
# 784, 786, 787
# 785, 787, 788
# 786, 788, 789
# 787, 789, 790
# 788, 790, 791
# 789, 791, 792
# 790, 792, 793
# 791, 793, 794
# 792, 794, 795
# 793, 795, 796
# 794, 796, 797
# 795, 797, 798
# 796, 798, 799
# 797, 799, 800
# 798, 800, 801
# 799, 801, 802
# 800, 802, 803
# 801, 803, 804
# 802, 804, 805
# 803, 805, 806
# 804, 806, 807
# 805, 807, 808
# 806, 808, 809
# 807, 809, 810
# 808, 810, 811
# 809, 811, 812
# 810, 812, 813
# 811, 813, 814
# 812, 814, 815
# 813, 815, 816
# 814, 816, 817
# 815, 817, 818
# 816, 818, 819
# 817, 819, 820
# 818, 820, 821
# 819, 821, 822
# 820, 822, 823
# 821, 823, 824
# 822, 824, 825
# 823, 825, 826
# 824, 826, 827
# 825, 827, 828
# 826, 828, 829
# 827, 829, 830
# 828, 830, 831
# 829, 831, 832
# 830, 832, 833
# 831, 833, 834
# 832, 834, 835
# 833, 835, 836
# 834, 836, 837
# ...

# %% [markdown]
# Columns

# %%
# Nodes for column 3
column_3_z_cord = np.arange(1, 52, 1)

# Nodes
for i in range(len(column_3_z_cord)):
    print(f"{i+978}, 372, 0, {column_3_z_cord[i]}")
# Out:
# 978, 372, 0, 1
# 979, 372, 0, 2
# 980, 372, 0, 3
# 981, 372, 0, 4
# 982, 372, 0, 5
# 983, 372, 0, 6
# 984, 372, 0, 7
# 985, 372, 0, 8
# 986, 372, 0, 9
# 987, 372, 0, 10
# 988, 372, 0, 11
# 989, 372, 0, 12
# 990, 372, 0, 13
# 991, 372, 0, 14
# 992, 372, 0, 15
# 993, 372, 0, 16
# 994, 372, 0, 17
# 995, 372, 0, 18
# 996, 372, 0, 19
# 997, 372, 0, 20
# 998, 372, 0, 21
# 999, 372, 0, 22
# 1000, 372, 0, 23
# 1001, 372, 0, 24
# 1002, 372, 0, 25
# 1003, 372, 0, 26
# 1004, 372, 0, 27
# 1005, 372, 0, 28
# 1006, 372, 0, 29
# 1007, 372, 0, 30
# 1008, 372, 0, 31
# 1009, 372, 0, 32
# 1010, 372, 0, 33
# 1011, 372, 0, 34
# 1012, 372, 0, 35
# 1013, 372, 0, 36
# 1014, 372, 0, 37
# 1015, 372, 0, 38
# 1016, 372, 0, 39
# 1017, 372, 0, 40
# 1018, 372, 0, 41
# 1019, 372, 0, 42
# 1020, 372, 0, 43
# 1021, 372, 0, 44
# 1022, 372, 0, 45
# 1023, 372, 0, 46
# 1024, 372, 0, 47
# 1025, 372, 0, 48
# 1026, 372, 0, 49
# 1027, 372, 0, 50
# 1028, 372, 0, 51

# %%
# Elements for column 3
for i in range(len(column_3_z_cord)-1):
    print(f"{i+980}, {i+978}, {i+979}")
# Out:
# 980, 978, 979
# 981, 979, 980
# 982, 980, 981
# 983, 981, 982
# 984, 982, 983
# 985, 983, 984
# 986, 984, 985
# 987, 985, 986
# 988, 986, 987
# 989, 987, 988
# 990, 988, 989
# 991, 989, 990
# 992, 990, 991
# 993, 991, 992
# 994, 992, 993
# 995, 993, 994
# 996, 994, 995
# 997, 995, 996
# 998, 996, 997
# 999, 997, 998
# 1000, 998, 999
# 1001, 999, 1000
# 1002, 1000, 1001
# 1003, 1001, 1002
# 1004, 1002, 1003
# 1005, 1003, 1004
# 1006, 1004, 1005
# 1007, 1005, 1006
# 1008, 1006, 1007
# 1009, 1007, 1008
# 1010, 1008, 1009
# 1011, 1009, 1010
# 1012, 1010, 1011
# 1013, 1011, 1012
# 1014, 1012, 1013
# 1015, 1013, 1014
# 1016, 1014, 1015
# 1017, 1015, 1016
# 1018, 1016, 1017
# 1019, 1017, 1018
# 1020, 1018, 1019
# 1021, 1019, 1020
# 1022, 1020, 1021
# 1023, 1021, 1022
# 1024, 1022, 1023
# 1025, 1023, 1024
# 1026, 1024, 1025
# 1027, 1025, 1026
# 1028, 1026, 1027
# 1029, 1027, 1028

# %%
# Nodes for column 4:
column_4_z_cord = np.arange(1, 52, 1)

# Nodes
for i in range(len(column_4_z_cord)):
    print(f"{i+1028}, 420, 0, {column_4_z_cord[i]}")
# Out:
# 1028, 420, 0, 1
# 1029, 420, 0, 2
# 1030, 420, 0, 3
# 1031, 420, 0, 4
# 1032, 420, 0, 5
# 1033, 420, 0, 6
# 1034, 420, 0, 7
# 1035, 420, 0, 8
# 1036, 420, 0, 9
# 1037, 420, 0, 10
# 1038, 420, 0, 11
# 1039, 420, 0, 12
# 1040, 420, 0, 13
# 1041, 420, 0, 14
# 1042, 420, 0, 15
# 1043, 420, 0, 16
# 1044, 420, 0, 17
# 1045, 420, 0, 18
# 1046, 420, 0, 19
# 1047, 420, 0, 20
# 1048, 420, 0, 21
# 1049, 420, 0, 22
# 1050, 420, 0, 23
# 1051, 420, 0, 24
# 1052, 420, 0, 25
# 1053, 420, 0, 26
# 1054, 420, 0, 27
# 1055, 420, 0, 28
# 1056, 420, 0, 29
# 1057, 420, 0, 30
# 1058, 420, 0, 31
# 1059, 420, 0, 32
# 1060, 420, 0, 33
# 1061, 420, 0, 34
# 1062, 420, 0, 35
# 1063, 420, 0, 36
# 1064, 420, 0, 37
# 1065, 420, 0, 38
# 1066, 420, 0, 39
# 1067, 420, 0, 40
# 1068, 420, 0, 41
# 1069, 420, 0, 42
# 1070, 420, 0, 43
# 1071, 420, 0, 44
# 1072, 420, 0, 45
# 1073, 420, 0, 46
# 1074, 420, 0, 47
# 1075, 420, 0, 48
# 1076, 420, 0, 49
# 1077, 420, 0, 50
# 1078, 420, 0, 51

# %%
# Elements for column 4
for i in range(len(column_4_z_cord)-1):
    print(f"{i+1030}, {i+1028}, {i+1029}")
# Out:
# 1030, 1028, 1029
# 1031, 1029, 1030
# 1032, 1030, 1031
# 1033, 1031, 1032
# 1034, 1032, 1033
# 1035, 1033, 1034
# 1036, 1034, 1035
# 1037, 1035, 1036
# 1038, 1036, 1037
# 1039, 1037, 1038
# 1040, 1038, 1039
# 1041, 1039, 1040
# 1042, 1040, 1041
# 1043, 1041, 1042
# 1044, 1042, 1043
# 1045, 1043, 1044
# 1046, 1044, 1045
# 1047, 1045, 1046
# 1048, 1046, 1047
# 1049, 1047, 1048
# 1050, 1048, 1049
# 1051, 1049, 1050
# 1052, 1050, 1051
# 1053, 1051, 1052
# 1054, 1052, 1053
# 1055, 1053, 1054
# 1056, 1054, 1055
# 1057, 1055, 1056
# 1058, 1056, 1057
# 1059, 1057, 1058
# 1060, 1058, 1059
# 1061, 1059, 1060
# 1062, 1060, 1061
# 1063, 1061, 1062
# 1064, 1062, 1063
# 1065, 1063, 1064
# 1066, 1064, 1065
# 1067, 1065, 1066
# 1068, 1066, 1067
# 1069, 1067, 1068
# 1070, 1068, 1069
# 1071, 1069, 1070
# 1072, 1070, 1071
# 1073, 1071, 1072
# 1074, 1072, 1073
# 1075, 1073, 1074
# 1076, 1074, 1075
# 1077, 1075, 1076
# 1078, 1076, 1077
# 1079, 1077, 1078

# %%
# Nodes for column 5:
column_5_z_cord = np.arange(11, 52, 1)

# Nodes
for i in range(len(column_5_z_cord)):
    print(f"{i+1078}, 468, 0, {column_5_z_cord[i]}")
# Out:
# 1078, 468, 0, 11
# 1079, 468, 0, 12
# 1080, 468, 0, 13
# 1081, 468, 0, 14
# 1082, 468, 0, 15
# 1083, 468, 0, 16
# 1084, 468, 0, 17
# 1085, 468, 0, 18
# 1086, 468, 0, 19
# 1087, 468, 0, 20
# 1088, 468, 0, 21
# 1089, 468, 0, 22
# 1090, 468, 0, 23
# 1091, 468, 0, 24
# 1092, 468, 0, 25
# 1093, 468, 0, 26
# 1094, 468, 0, 27
# 1095, 468, 0, 28
# 1096, 468, 0, 29
# 1097, 468, 0, 30
# 1098, 468, 0, 31
# 1099, 468, 0, 32
# 1100, 468, 0, 33
# 1101, 468, 0, 34
# 1102, 468, 0, 35
# 1103, 468, 0, 36
# 1104, 468, 0, 37
# 1105, 468, 0, 38
# 1106, 468, 0, 39
# 1107, 468, 0, 40
# 1108, 468, 0, 41
# 1109, 468, 0, 42
# 1110, 468, 0, 43
# 1111, 468, 0, 44
# 1112, 468, 0, 45
# 1113, 468, 0, 46
# 1114, 468, 0, 47
# 1115, 468, 0, 48
# 1116, 468, 0, 49
# 1117, 468, 0, 50
# 1118, 468, 0, 51

# %%
# Elements for column 5
for i in range(len(column_5_z_cord)-2):
    print(f"{i+1080}, {i+1078}, {i+1079}")
# Out:
# 1080, 1078, 1079
# 1081, 1079, 1080
# 1082, 1080, 1081
# 1083, 1081, 1082
# 1084, 1082, 1083
# 1085, 1083, 1084
# 1086, 1084, 1085
# 1087, 1085, 1086
# 1088, 1086, 1087
# 1089, 1087, 1088
# 1090, 1088, 1089
# 1091, 1089, 1090
# 1092, 1090, 1091
# 1093, 1091, 1092
# 1094, 1092, 1093
# 1095, 1093, 1094
# 1096, 1094, 1095
# 1097, 1095, 1096
# 1098, 1096, 1097
# 1099, 1097, 1098
# 1100, 1098, 1099
# 1101, 1099, 1100
# 1102, 1100, 1101
# 1103, 1101, 1102
# 1104, 1102, 1103
# 1105, 1103, 1104
# 1106, 1104, 1105
# 1107, 1105, 1106
# 1108, 1106, 1107
# 1109, 1107, 1108
# 1110, 1108, 1109
# 1111, 1109, 1110
# 1112, 1110, 1111
# 1113, 1111, 1112
# 1114, 1112, 1113
# 1115, 1113, 1114
# 1116, 1114, 1115
# 1117, 1115, 1116
# 1118, 1116, 1117

# %%
# Nodes for column 6:
column_6_z_cord = np.arange(24, 52, 1)

# Nodes
for i in range(len(column_6_z_cord)):
    print(f"{i+1118}, 516, 0, {column_6_z_cord[i]}")
# Out:
# 1118, 516, 0, 24
# 1119, 516, 0, 25
# 1120, 516, 0, 26
# 1121, 516, 0, 27
# 1122, 516, 0, 28
# 1123, 516, 0, 29
# 1124, 516, 0, 30
# 1125, 516, 0, 31
# 1126, 516, 0, 32
# 1127, 516, 0, 33
# 1128, 516, 0, 34
# 1129, 516, 0, 35
# 1130, 516, 0, 36
# 1131, 516, 0, 37
# 1132, 516, 0, 38
# 1133, 516, 0, 39
# 1134, 516, 0, 40
# 1135, 516, 0, 41
# 1136, 516, 0, 42
# 1137, 516, 0, 43
# 1138, 516, 0, 44
# 1139, 516, 0, 45
# 1140, 516, 0, 46
# 1141, 516, 0, 47
# 1142, 516, 0, 48
# 1143, 516, 0, 49
# 1144, 516, 0, 50
# 1145, 516, 0, 51

# %%
# Elements for column 6
for i in range(len(column_6_z_cord)-2):
    print(f"{i+1120}, {i+1118}, {i+1119}")
# Out:
# 1120, 1118, 1119
# 1121, 1119, 1120
# 1122, 1120, 1121
# 1123, 1121, 1122
# 1124, 1122, 1123
# 1125, 1123, 1124
# 1126, 1124, 1125
# 1127, 1125, 1126
# 1128, 1126, 1127
# 1129, 1127, 1128
# 1130, 1128, 1129
# 1131, 1129, 1130
# 1132, 1130, 1131
# 1133, 1131, 1132
# 1134, 1132, 1133
# 1135, 1133, 1134
# 1136, 1134, 1135
# 1137, 1135, 1136
# 1138, 1136, 1137
# 1139, 1137, 1138
# 1140, 1138, 1139
# 1141, 1139, 1140
# 1142, 1140, 1141
# 1143, 1141, 1142
# 1144, 1142, 1143
# 1145, 1143, 1144

# %%
# Nodes for column 7:
column_7_z_cord = np.arange(33, 51, 1)

# Nodes
for i in range(len(column_7_z_cord)):
    print(f"{i+1145}, 564, 0, {column_7_z_cord[i]}")
# Out:
# 1145, 564, 0, 33
# 1146, 564, 0, 34
# 1147, 564, 0, 35
# 1148, 564, 0, 36
# 1149, 564, 0, 37
# 1150, 564, 0, 38
# 1151, 564, 0, 39
# 1152, 564, 0, 40
# 1153, 564, 0, 41
# 1154, 564, 0, 42
# 1155, 564, 0, 43
# 1156, 564, 0, 44
# 1157, 564, 0, 45
# 1158, 564, 0, 46
# 1159, 564, 0, 47
# 1160, 564, 0, 48
# 1161, 564, 0, 49
# 1162, 564, 0, 50

# %%
# Elements for column 7
for i in range(len(column_7_z_cord)-1):
    print(f"{i+1147}, {i+1145}, {i+1146}")
# Out:
# 1147, 1145, 1146
# 1148, 1146, 1147
# 1149, 1147, 1148
# 1150, 1148, 1149
# 1151, 1149, 1150
# 1152, 1150, 1151
# 1153, 1151, 1152
# 1154, 1152, 1153
# 1155, 1153, 1154
# 1156, 1154, 1155
# 1157, 1155, 1156
# 1158, 1156, 1157
# 1159, 1157, 1158
# 1160, 1158, 1159
# 1161, 1159, 1160
# 1162, 1160, 1161
# 1163, 1161, 1162

# %% [markdown]
# Cables

# %%
for i in range(13):
    print(f"{i+1194}, ")
# Out:
# 1194,
# 1195,
# 1196,
# 1197,
# 1198,
# 1199,
# 1200,
# 1201,
# 1202,
# 1203,
# 1204,
# 1205,
# 1206,

# %%
x = 609-358

for i in range(x):
    print(i+359)
# Out:
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400
# 401
# 402
# 403
# 404
# 405
# 406
# 407
# 408
# 409
# 410
# 411
# 412
# 413
# 414
# 415
# 416
# 417
# 418
# 419
# 420
# 421
# 422
# 423
# 424
# 425
# 426
# 427
# 428
# 429
# 430
# 431
# 432
# 433
# 434
# 435
# 436
# 437
# 438
# 439
# 440
# 441
# 442
# 443
# 444
# 445
# 446
# 447
# 448
# 449
# 450
# 451
# 452
# 453
# 454
# 455
# 456
# 457
# 458
# 459
# 460
# 461
# 462
# 463
# 464
# 465
# 466
# 467
# 468
# 469
# 470
# 471
# 472
# 473
# 474
# 475
# 476
# 477
# 478
# 479
# 480
# 481
# 482
# 483
# 484
# 485
# 486
# 487
# 488
# 489
# 490
# 491
# 492
# 493
# 494
# 495
# 496
# 497
# 498
# 499
# 500
# 501
# 502
# 503
# 504
# 505
# 506
# 507
# 508
# 509
# 510
# 511
# 512
# 513
# 514
# 515
# 516
# 517
# 518
# 519
# 520
# 521
# 522
# 523
# 524
# ...

# %%
for i in range(608):
    print(f"{i+1207}, {i+1}, {i+2}")
# Out:
# 1207, 1, 2
# 1208, 2, 3
# 1209, 3, 4
# 1210, 4, 5
# 1211, 5, 6
# 1212, 6, 7
# 1213, 7, 8
# 1214, 8, 9
# 1215, 9, 10
# 1216, 10, 11
# 1217, 11, 12
# 1218, 12, 13
# 1219, 13, 14
# 1220, 14, 15
# 1221, 15, 16
# 1222, 16, 17
# 1223, 17, 18
# 1224, 18, 19
# 1225, 19, 20
# 1226, 20, 21
# 1227, 21, 22
# 1228, 22, 23
# 1229, 23, 24
# 1230, 24, 25
# 1231, 25, 26
# 1232, 26, 27
# 1233, 27, 28
# 1234, 28, 29
# 1235, 29, 30
# 1236, 30, 31
# 1237, 31, 32
# 1238, 32, 33
# 1239, 33, 34
# 1240, 34, 35
# 1241, 35, 36
# 1242, 36, 37
# 1243, 37, 38
# 1244, 38, 39
# 1245, 39, 40
# 1246, 40, 41
# 1247, 41, 42
# 1248, 42, 43
# 1249, 43, 44
# 1250, 44, 45
# 1251, 45, 46
# 1252, 46, 47
# 1253, 47, 48
# 1254, 48, 49
# 1255, 49, 50
# 1256, 50, 51
# 1257, 51, 52
# 1258, 52, 53
# 1259, 53, 54
# 1260, 54, 55
# 1261, 55, 56
# 1262, 56, 57
# 1263, 57, 58
# 1264, 58, 59
# 1265, 59, 60
# 1266, 60, 61
# 1267, 61, 62
# 1268, 62, 63
# 1269, 63, 64
# 1270, 64, 65
# 1271, 65, 66
# 1272, 66, 67
# 1273, 67, 68
# ...

# %%
for i in range(15):
    print(f"{i+1190},")
# Out:
# 1190,
# 1191,
# 1192,
# 1193,
# 1194,
# 1195,
# 1196,
# 1197,
# 1198,
# 1199,
# 1200,
# 1201,
# 1202,
# 1203,
# 1204,
